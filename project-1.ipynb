# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error ,mean_squared_error

data =pd.read_csv("student.csv")

X = data[['Study_Hours']]
y = data['Total_Score']

model =LinearRegression()

model.fit(X,y)
predicted_score = model.predict(X)

mae= mean_absolute_error(y , predicted_score)
mse= mean_squared_error(y , predicted_score)
rmse = np.sqrt(mse)

print(mae)
print(mse)
print(rmse)

new_hour= float(input("enter the hour"))
new_pred= model.predict([[new_hour]])
print(f" prediction for { new_hour} is {new_pred}")
# Out:
# 9.607532998879742
# 126.39149578685891
# 11.242397243775853
# enter the hour 7
#  prediction for 7.0 is [76.72178657]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
